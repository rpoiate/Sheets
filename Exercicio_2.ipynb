# %% [markdown]
# <a href="https://colab.research.google.com/github/rpoiate/Sheets/blob/main/Exercicio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Carregue as duas planilhas do Exceldf1 = pd.read_excel('caminho/para/planilha1.xlsx')
df1 = pd.read_csv('student-mat.csv',sep=';')
df2 = pd.read_csv('student-por.csv',sep=';')
# Use a função concat para mesclar as duas planilhasdf = pd.concat([df1, df2])
# Exiba a planilha mescladaprint(df)

# %%
df_merged = pd.merge(df1, df2, left_index=True, right_index=True)

# %%
df_merged.head(490)
# Out:
#     school_x sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x  \
# 0         GP     F     18         U       GT3         A       4       4
# 1         GP     F     17         U       GT3         T       1       1
# 2         GP     F     15         U       LE3         T       1       1
# 3         GP     F     15         U       GT3         T       4       2
# 4         GP     F     16         U       GT3         T       3       3
# ..       ...   ...    ...       ...       ...       ...     ...     ...
# 390       MS     M     20         U       LE3         A       2       2
# 391       MS     M     17         U       LE3         T       3       1
# 392       MS     M     21         R       GT3         T       1       1
# 393       MS     M     18         R       LE3         T       3       2
# 394       MS     M     19         U       LE3         T       1       1
#
#        Mjob_x    Fjob_x  ... famrel_y freetime_y  goout_y  Dalc_y  Walc_y  \
# ...

# %%
#Qual a média de idade ?

# %%
media = df_merged['age_x'].mean()
print(media)
# Out:
# 16.696202531645568

# %%
#Quantas Mjob são health?

# %%
contagem_health = (df_merged['Mjob_x'] == 'health').sum()
print(contagem_health)
# Out:
# 34

# %%
#Quantas Fjob são service?

# %%
contagem_service = (df_merged['Fjob_x'] == 'services').sum()
print(contagem_service)
# Out:
# 111
